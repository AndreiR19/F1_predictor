# %%
# Import all the required libraries
import fastf1
import pandas as pd     

# Enable caching for faster data loading
fastf1.Cache.enable_cache('cache')

# %%
# Import te results df
results_df = pd.read_csv('DATA/f1_results_2024_2025.csv')
results_df.describe
# Out:
# <bound method NDFrame.describe of      DriverNumber BroadcastName Abbreviation         DriverId  \
# 0              11       S PEREZ          PER            perez
# 1              24        G ZHOU          ZHO             zhou
# 2              20   K MAGNUSSEN          MAG  kevin_magnussen
# 3               3   D RICCIARDO          RIC        ricciardo
# 4              77      V BOTTAS          BOT           bottas
# ..            ...           ...          ...              ...
# 170            22     Y TSUNODA          TSU          tsunoda
# 171            14      F ALONSO          ALO           alonso
# 172            16     C LECLERC          LEC          leclerc
# 173            44    L HAMILTON          HAM         hamilton
# 174            10       P GASLY          GAS            gasly
#
#             TeamName TeamColor        TeamId FirstName   LastName  \
# 0    Red Bull Racing    3671c6      red_bull    Sergio      Perez
# 1        Kick Sauber    52e252        sauber    Guanyu       Zhou
# 2       Haas F1 Team    b6babd          haas     Kevin  Magnussen
# 3                 RB    6692ff            rb    Daniel  Ricciardo
# 4        Kick Sauber    52e252        sauber  Valtteri     Bottas
# ..               ...       ...           ...       ...        ...
# 170     Racing Bulls    6692FF            rb      Yuki    Tsunoda
# 171     Aston Martin    229971  aston_martin  Fernando     Alonso
# 172          Ferrari    E80020       ferrari   Charles    Leclerc
# 173          Ferrari    E80020       ferrari     Lewis   Hamilton
# 174           Alpine    0093CC        alpine    Pierre      Gasly
#
#              FullName  ... Position ClassifiedPosition  GridPosition  Q1  Q2  \
# 0        Sergio Perez  ...      2.0                  2           5.0 NaN NaN
# 1         Guanyu Zhou  ...     11.0                 11          17.0 NaN NaN
# 2     Kevin Magnussen  ...     12.0                 12          15.0 NaN NaN
# 3    Daniel Ricciardo  ...     13.0                 13          14.0 NaN NaN
# 4     Valtteri Bottas  ...     19.0                 19          16.0 NaN NaN
# ..                ...  ...      ...                ...           ...  ..  ..
# 170      Yuki Tsunoda  ...     16.0                 16           9.0 NaN NaN
# 171   Fernando Alonso  ...     17.0                  R          13.0 NaN NaN
# 172   Charles Leclerc  ...     18.0                  D           6.0 NaN NaN
# 173    Lewis Hamilton  ...     19.0                  D           5.0 NaN NaN
# 174      Pierre Gasly  ...     20.0                  D          16.0 NaN NaN
#
#      Q3                    Time        Status Points Round
# 0   NaN  0 days 00:00:22.457000      Finished   18.0     1
# 1   NaN  0 days 00:00:06.759000        Lapped    0.0     1
# 2   NaN  0 days 00:00:08.316000        Lapped    0.0     1
# 3   NaN  0 days 00:00:08.958000        Lapped    0.0     1
# 4   NaN  0 days 00:01:23.230000        Lapped    0.0     1
# ..   ..                     ...           ...    ...   ...
# 170 NaN  0 days 00:00:23.511000        Lapped    0.0     2
# 171 NaN                     NaN       Retired    0.0     2
# 172 NaN                     NaN  Disqualified    0.0     2
# 173 NaN                     NaN  Disqualified    0.0     2
# 174 NaN                     NaN  Disqualified    0.0     2
#
# [175 rows x 22 columns]>

# %%
# %pip install openpyxl

# Load driver data from an Excel file
drivers = pd.read_excel('DATA/f1_drivers_points_exp.xlsx')
drivers
# Out:
# Requirement already satisfied: openpyxl in c:\users\marius radulescu\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\marius radulescu\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
#            DriverName Abbreviation        TeamId  DriverExperience
# 0      Max Verstappen          VER      red_bull                11
# 1      Lewis Hamilton          HAM       ferrari                19
# 2     Charles Leclerc          LEC       ferrari                 8
# 3        Carlos Sainz          SAI      williams                11
# 4        Lando Norris          NOR       mclaren                 7
# 5      George Russell          RUS      mercedes                 7
# 6     Fernando Alonso          ALO  aston_martin                22
# 7       Oscar Piastri          PIA       mclaren                 3
# 8        Esteban Ocon          OCO          haas                 9
# 9        Pierre Gasly          GAS        alpine                 9
# 10       Lance Stroll          STR  aston_martin                 9
# 11       Yuki Tsunoda          TSU            rb                 5
# 12    Alexander Albon          ALB      williams                 6
# 13    Nico Hülkenberg          HUL        sauber                13
# 14     Oliver Bearman          BEA          haas                 1
# 15        Liam Lawson          LAW      red_bull                 2
# 16  Gabriel Bortoleto          BOR        sauber                 1
# 17     Kimi Antonelli          ANT      mercedes                 1
# 18        Jack Doohan          DOO        alpine                 1
# 19       Isack Hadjar          HAD            rb                 1

# %%
filtered_results = results_df[results_df['Abbreviation'].isin(drivers['Abbreviation'])]

# Group by driver and sum total points
total_points = filtered_results.groupby('Abbreviation')['Points'].sum().reset_index()

# Fill the missing rookie drivers with 0 points
all_drivers_df = pd.DataFrame({'Abbreviation': drivers['Abbreviation']})
total_points = all_drivers_df.merge(total_points, on = 'Abbreviation', how = 'left').fillna(0)

# Convert points to absolute value integer for simplerer point system
total_points["Points"] = total_points["Points"].astype(int)
total_points = total_points.sort_values(by="Points", ascending=False)

total_points
# Out:
#    Abbreviation  Points
# 4           NOR      43
# 0           VER      30
# 5           RUS      30
# 7           PIA      27
# 17          ANT      20
# 12          ALB      16
# 8           OCO      10
# 10          STR      10
# 13          HUL       6
# 14          BEA       4
# 2           LEC       4
# 1           HAM       1
# 3           SAI       1
# 6           ALO       0
# 9           GAS       0
# 11          TSU       0
# 15          LAW       0
# 16          BOR       0
# 18          DOO       0
# 19          HAD       0

# %%
drivers = total_points.merge(drivers, on = 'Abbreviation', how = 'left').fillna(0)
drivers
# Out:
#    Abbreviation  Points         DriverName        TeamId  DriverExperience
# 0           NOR      43       Lando Norris       mclaren                 7
# 1           VER      30     Max Verstappen      red_bull                11
# 2           RUS      30     George Russell      mercedes                 7
# 3           PIA      27      Oscar Piastri       mclaren                 3
# 4           ANT      20     Kimi Antonelli      mercedes                 1
# 5           ALB      16    Alexander Albon      williams                 6
# 6           OCO      10       Esteban Ocon          haas                 9
# 7           STR      10       Lance Stroll  aston_martin                 9
# 8           HUL       6    Nico Hülkenberg        sauber                13
# 9           BEA       4     Oliver Bearman          haas                 1
# 10          LEC       4    Charles Leclerc       ferrari                 8
# 11          HAM       1     Lewis Hamilton       ferrari                19
# 12          SAI       1       Carlos Sainz      williams                11
# 13          ALO       0    Fernando Alonso  aston_martin                22
# 14          GAS       0       Pierre Gasly        alpine                 9
# 15          TSU       0       Yuki Tsunoda            rb                 5
# 16          LAW       0        Liam Lawson      red_bull                 2
# 17          BOR       0  Gabriel Bortoleto        sauber                 1
# 18          DOO       0        Jack Doohan        alpine                 1
# 19          HAD       0       Isack Hadjar            rb                 1

# %%
# Calculate average qualifying position for each driver
avg_quali_df = results_df.groupby('Abbreviation')['GridPosition'].mean().reset_index()
avg_quali_df.rename(columns = {'GridPosition': 'AvgQualiPosition'}, inplace = True)

# %%
# Calculate average race position for each driver
avg_race_df = results_df.groupby('Abbreviation')['Position'].mean().reset_index()
avg_race_df.rename(columns={'Position': 'AvgRacePosition'}, inplace=True)

# %%
# Merge both dataframes
avg_pos_df = avg_quali_df.merge(avg_race_df, on = 'Abbreviation', how = 'outer')

# Merge the drivers DataFrame with avg_pos_df to include AvgQualiPosition and AvgRacePosition
drivers = drivers.merge(avg_pos_df, on = 'Abbreviation', how = 'left')

drivers
# Out:
#    Abbreviation  Points         DriverName        TeamId  DriverExperience  \
# 0           NOR      43       Lando Norris       mclaren                 7
# 1           VER      30     Max Verstappen      red_bull                11
# 2           RUS      30     George Russell      mercedes                 7
# 3           PIA      27      Oscar Piastri       mclaren                 3
# 4           ANT      20     Kimi Antonelli      mercedes                 1
# 5           ALB      16    Alexander Albon      williams                 6
# 6           OCO      10       Esteban Ocon          haas                 9
# 7           STR      10       Lance Stroll  aston_martin                 9
# 8           HUL       6    Nico Hülkenberg        sauber                13
# 9           BEA       4     Oliver Bearman          haas                 1
# 10          LEC       4    Charles Leclerc       ferrari                 8
# 11          HAM       1     Lewis Hamilton       ferrari                19
# 12          SAI       1       Carlos Sainz      williams                11
# 13          ALO       0    Fernando Alonso  aston_martin                22
# 14          GAS       0       Pierre Gasly        alpine                 9
# 15          TSU       0       Yuki Tsunoda            rb                 5
# 16          LAW       0        Liam Lawson      red_bull                 2
# 17          BOR       0  Gabriel Bortoleto        sauber                 1
# 18          DOO       0        Jack Doohan        alpine                 1
# 19          HAD       0       Isack Hadjar            rb                 1
#
#     AvgQualiPosition  AvgRacePosition
# 0                2.0              1.5
# 1                3.5              3.0
# 2                3.0              3.0
# 3                1.5              5.0
# 4               12.0              5.0
# 5                8.0              6.0
# 6               15.0              9.0
# 7               13.5              7.5
# 8               14.5             11.0
# 9               18.5             11.0
# 10               6.5             13.0
# 11               6.5             14.5
# 12              12.5             14.0
# 13              12.5             17.0
# 14              12.5             15.5
# 15               7.0             14.0
# 16              19.0             13.5
# 17              17.0             15.0
# 18              16.0             16.0
# 19               9.0             15.5

# %%
filtered_drivers_info = drivers.drop(['DriverExperience'], axis = 1)
filtered_drivers_info
# Out:
#    Abbreviation  Points         DriverName        TeamId  AvgQualiPosition  \
# 0           NOR      43       Lando Norris       mclaren               2.0
# 1           VER      30     Max Verstappen      red_bull               3.5
# 2           RUS      30     George Russell      mercedes               3.0
# 3           PIA      27      Oscar Piastri       mclaren               1.5
# 4           ANT      20     Kimi Antonelli      mercedes              12.0
# 5           ALB      16    Alexander Albon      williams               8.0
# 6           OCO      10       Esteban Ocon          haas              15.0
# 7           STR      10       Lance Stroll  aston_martin              13.5
# 8           HUL       6    Nico Hülkenberg        sauber              14.5
# 9           BEA       4     Oliver Bearman          haas              18.5
# 10          LEC       4    Charles Leclerc       ferrari               6.5
# 11          HAM       1     Lewis Hamilton       ferrari               6.5
# 12          SAI       1       Carlos Sainz      williams              12.5
# 13          ALO       0    Fernando Alonso  aston_martin              12.5
# 14          GAS       0       Pierre Gasly        alpine              12.5
# 15          TSU       0       Yuki Tsunoda            rb               7.0
# 16          LAW       0        Liam Lawson      red_bull              19.0
# 17          BOR       0  Gabriel Bortoleto        sauber              17.0
# 18          DOO       0        Jack Doohan        alpine              16.0
# 19          HAD       0       Isack Hadjar            rb               9.0
#
#     AvgRacePosition
# 0               1.5
# 1               3.0
# 2               3.0
# 3               5.0
# 4               5.0
# 5               6.0
# 6               9.0
# 7               7.5
# 8              11.0
# 9              11.0
# 10             13.0
# 11             14.5
# 12             14.0
# 13             17.0
# 14             15.5
# 15             14.0
# 16             13.5
# 17             15.0
# 18             16.0
# 19             15.5

# %%
filtered_drivers_info.to_csv('DATA/filtred_drivers_info.csv')

# %%
# Select only relevant features from results_df for further processing
filtered_results_df = results_df[['Round', 'Abbreviation', 'GridPosition', 'Position']]
filtered_results_df
# Out:
#      Round Abbreviation  GridPosition  Position
# 0        1          PER           5.0       2.0
# 1        1          ZHO          17.0      11.0
# 2        1          MAG          15.0      12.0
# 3        1          RIC          14.0      13.0
# 4        1          BOT          16.0      19.0
# ..     ...          ...           ...       ...
# 170      2          TSU           9.0      16.0
# 171      2          ALO          13.0      17.0
# 172      2          LEC           6.0      18.0
# 173      2          HAM           5.0      19.0
# 174      2          GAS          16.0      20.0
#
# [175 rows x 4 columns]

# %%
# Merge the filtered race results with driver information using 'Abbreviation' as the key
# This combines race performance with driver statistics and gives the final dataset to use for prediction
final_df = filtered_results_df.merge(filtered_drivers_info, on = 'Abbreviation', how = 'inner' )
final_df[:10]
# Out:
#    Round Abbreviation  GridPosition  Position  Points       DriverName  \
# 0      1          NOR           1.0       1.0      43     Lando Norris
# 1      1          VER           3.0       2.0      30   Max Verstappen
# 2      1          RUS           4.0       3.0      30   George Russell
# 3      1          ANT          16.0       4.0      20   Kimi Antonelli
# 4      1          ALB           6.0       5.0      16  Alexander Albon
# 5      1          STR          13.0       6.0      10     Lance Stroll
# 6      1          HUL          17.0       7.0       6  Nico Hülkenberg
# 7      1          LEC           7.0       8.0       4  Charles Leclerc
# 8      1          PIA           2.0       9.0      27    Oscar Piastri
# 9      1          HAM           8.0      10.0       1   Lewis Hamilton
#
#          TeamId  AvgQualiPosition  AvgRacePosition
# 0       mclaren               2.0              1.5
# 1      red_bull               3.5              3.0
# 2      mercedes               3.0              3.0
# 3      mercedes              12.0              5.0
# 4      williams               8.0              6.0
# 5  aston_martin              13.5              7.5
# 6        sauber              14.5             11.0
# 7       ferrari               6.5             13.0
# 8       mclaren               1.5              5.0
# 9       ferrari               6.5             14.5

# %%
final_df["QualifyingScore"] = (final_df["AvgQualiPosition"] + final_df["GridPosition"]) / 2
final_df
# Out:
#     Round Abbreviation  GridPosition  Position  Points         DriverName  \
# 0       1          NOR           1.0       1.0      43       Lando Norris
# 1       1          VER           3.0       2.0      30     Max Verstappen
# 2       1          RUS           4.0       3.0      30     George Russell
# 3       1          ANT          16.0       4.0      20     Kimi Antonelli
# 4       1          ALB           6.0       5.0      16    Alexander Albon
# 5       1          STR          13.0       6.0      10       Lance Stroll
# 6       1          HUL          17.0       7.0       6    Nico Hülkenberg
# 7       1          LEC           7.0       8.0       4    Charles Leclerc
# 8       1          PIA           2.0       9.0      27      Oscar Piastri
# 9       1          HAM           8.0      10.0       1     Lewis Hamilton
# 10      1          GAS           9.0      11.0       0       Pierre Gasly
# 11      1          TSU           5.0      12.0       0       Yuki Tsunoda
# 12      1          OCO          19.0      13.0      10       Esteban Ocon
# 13      1          BEA          20.0      14.0       4     Oliver Bearman
# 14      1          LAW          18.0      15.0       0        Liam Lawson
# 15      1          BOR          15.0      16.0       0  Gabriel Bortoleto
# 16      1          ALO          12.0      17.0       0    Fernando Alonso
# 17      1          SAI          10.0      18.0       1       Carlos Sainz
# 18      1          DOO          14.0      19.0       0        Jack Doohan
# 19      1          HAD          11.0      20.0       0       Isack Hadjar
# 20      2          PIA           1.0       1.0      27      Oscar Piastri
# 21      2          NOR           3.0       2.0      43       Lando Norris
# 22      2          RUS           2.0       3.0      30     George Russell
# 23      2          VER           4.0       4.0      30     Max Verstappen
# 24      2          OCO          11.0       5.0      10       Esteban Ocon
# 25      2          ANT           8.0       6.0      20     Kimi Antonelli
# 26      2          ALB          10.0       7.0      16    Alexander Albon
# 27      2          BEA          17.0       8.0       4     Oliver Bearman
# 28      2          STR          14.0       9.0      10       Lance Stroll
# 29      2          SAI          15.0      10.0       1       Carlos Sainz
# 30      2          HAD           7.0      11.0       0       Isack Hadjar
# 31      2          LAW          20.0      12.0       0        Liam Lawson
# 32      2          DOO          18.0      13.0       0        Jack Doohan
# 33      2          BOR          19.0      14.0       0  Gabriel Bortoleto
# 34      2          HUL          12.0      15.0       6    Nico Hülkenberg
# 35      2          TSU           9.0      16.0       0       Yuki Tsunoda
# 36      2          ALO          13.0      17.0       0    Fernando Alonso
# 37      2          LEC           6.0      18.0       4    Charles Leclerc
# 38      2          HAM           5.0      19.0       1     Lewis Hamilton
# 39      2          GAS          16.0      20.0       0       Pierre Gasly
#
#           TeamId  AvgQualiPosition  AvgRacePosition  QualifyingScore
# 0        mclaren               2.0              1.5             1.50
# 1       red_bull               3.5              3.0             3.25
# 2       mercedes               3.0              3.0             3.50
# 3       mercedes              12.0              5.0            14.00
# 4       williams               8.0              6.0             7.00
# 5   aston_martin              13.5              7.5            13.25
# 6         sauber              14.5             11.0            15.75
# 7        ferrari               6.5             13.0             6.75
# 8        mclaren               1.5              5.0             1.75
# 9        ferrari               6.5             14.5             7.25
# 10        alpine              12.5             15.5            10.75
# 11            rb               7.0             14.0             6.00
# 12          haas              15.0              9.0            17.00
# 13          haas              18.5             11.0            19.25
# 14      red_bull              19.0             13.5            18.50
# 15        sauber              17.0             15.0            16.00
# 16  aston_martin              12.5             17.0            12.25
# 17      williams              12.5             14.0            11.25
# 18        alpine              16.0             16.0            15.00
# 19            rb               9.0             15.5            10.00
# 20       mclaren               1.5              5.0             1.25
# 21       mclaren               2.0              1.5             2.50
# 22      mercedes               3.0              3.0             2.50
# 23      red_bull               3.5              3.0             3.75
# 24          haas              15.0              9.0            13.00
# 25      mercedes              12.0              5.0            10.00
# 26      williams               8.0              6.0             9.00
# 27          haas              18.5             11.0            17.75
# 28  aston_martin              13.5              7.5            13.75
# 29      williams              12.5             14.0            13.75
# 30            rb               9.0             15.5             8.00
# 31      red_bull              19.0             13.5            19.50
# 32        alpine              16.0             16.0            17.00
# 33        sauber              17.0             15.0            18.00
# 34        sauber              14.5             11.0            13.25
# 35            rb               7.0             14.0             8.00
# 36  aston_martin              12.5             17.0            12.75
# 37       ferrari               6.5             13.0             6.25
# 38       ferrari               6.5             14.5             5.75
# 39        alpine              12.5             15.5            14.25

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Round             40 non-null     int64
#  1   Abbreviation      40 non-null     object
#  2   GridPosition      40 non-null     float64
#  3   Position          40 non-null     float64
#  4   Points            40 non-null     int32
#  5   DriverName        40 non-null     object
#  6   TeamId            40 non-null     object
#  7   AvgQualiPosition  40 non-null     float64
#  8   AvgRacePosition   40 non-null     float64
#  9   QualifyingScore   40 non-null     float64
# dtypes: float64(5), int32(1), int64(1), object(3)
# memory usage: 3.1+ KB

# %%
# Count and find if there are any null values in the dataset
final_df.isnull().sum()
# Out:
# Round               0
# Abbreviation        0
# GridPosition        0
# Position            0
# Points              0
# DriverName          0
# TeamId              0
# AvgQualiPosition    0
# AvgRacePosition     0
# QualifyingScore     0
# dtype: int64

# %%
final_df.to_csv('DATA/f1_final_data.csv', index=False)
